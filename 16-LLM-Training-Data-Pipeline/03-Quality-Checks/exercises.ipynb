# %% [markdown]
# # Quality Checks - Exercises
#
# Ten graded exercises for the approved Chapter 16 TOC.

# %%
import json
import hashlib
import re
import numpy as np
from collections import Counter, defaultdict

def header(title):
    print("\n" + "=" * 72)
    print(title)
    print("=" * 72)

def stable_hash(value):
    if not isinstance(value, str):
        value = json.dumps(value, sort_keys=True)
    return hashlib.sha256(value.encode("utf-8")).hexdigest()

def token_count(text):
    return len(re.findall(r"\S+", text))

def check_true(name, condition):
    ok = bool(condition)
    print(f"{'PASS' if ok else 'FAIL'} - {name}")
    return ok

def check_close(name, value, expected, tol=1e-6):
    ok = np.allclose(value, expected, atol=tol, rtol=tol)
    print(f"{'PASS' if ok else 'FAIL'} - {name}: value={value}, expected={expected}")
    return ok

print("Exercise helpers ready.")

# %% [markdown]
# ## Exercise 1: Quality Score Check (*)
#
# Build a synthetic quality score example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 1: Quality Score Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: quality score checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 2: Filter Check (*)
#
# Build a synthetic filter example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 2: Filter Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: filter checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 3: Acceptance Rate Check (*)
#
# Build a synthetic acceptance rate example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 3: Acceptance Rate Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: acceptance rate checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 4: Pii Check (**)
#
# Build a synthetic PII example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 4: Pii Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: PII checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 5: Toxicity Check (**)
#
# Build a synthetic toxicity example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 5: Toxicity Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: toxicity checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 6: Threshold Check (**)
#
# Build a synthetic threshold example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 6: Threshold Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: threshold checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 7: Audit Check (**)
#
# Build a synthetic audit example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 7: Audit Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: audit checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 8: Quality Score Check (***)
#
# Build a synthetic quality score example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 8: Quality Score Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: quality score checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 9: Filter Check (***)
#
# Build a synthetic filter example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 9: Filter Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: filter checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 10: Acceptance Rate Check (***)
#
# Build a synthetic acceptance rate example, compute a validation statistic, and explain the pipeline implication.

# %%
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
header("Exercise 10: Acceptance Rate Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: acceptance rate checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")
