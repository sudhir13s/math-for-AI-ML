# %% [markdown]
# # Full Dataset Assembly - Exercises
#
# Ten graded exercises for the approved Chapter 16 TOC.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

try:
    import seaborn as sns
    sns.set_theme(style="whitegrid", palette="colorblind")
    HAS_SNS = True
except ImportError:
    plt.style.use("seaborn-v0_8-whitegrid")
    HAS_SNS = False

mpl.rcParams.update({
    "figure.figsize":    (10, 6),
    "figure.dpi":         120,
    "font.size":           13,
    "axes.titlesize":      15,
    "axes.labelsize":      13,
    "xtick.labelsize":     11,
    "ytick.labelsize":     11,
    "legend.fontsize":     11,
    "legend.framealpha":   0.85,
    "lines.linewidth":      2.0,
    "axes.spines.top":     False,
    "axes.spines.right":   False,
    "savefig.bbox":       "tight",
    "savefig.dpi":         150,
})
np.random.seed(42)
print("Plot setup complete.")

# %%
import json
import hashlib
import re
import numpy as np
from collections import Counter, defaultdict

def header(title):
    print("\n" + "=" * 72)
    print(title)
    print("=" * 72)

def stable_hash(value):
    if not isinstance(value, str):
        value = json.dumps(value, sort_keys=True)
    return hashlib.sha256(value.encode("utf-8")).hexdigest()

def token_count(text):
    return len(re.findall(r"\S+", text))

def check_true(name, condition):
    ok = bool(condition)
    print(f"{'PASS' if ok else 'FAIL'} - {name}")
    return ok

def check_close(name, value, expected, tol=1e-6):
    ok = np.allclose(value, expected, atol=tol, rtol=tol)
    print(f"{'PASS' if ok else 'FAIL'} - {name}: value={value}, expected={expected}")
    return ok

print("Exercise helpers ready.")

# %% [markdown]
# ## Exercise 1: Source Set Check (*)
#
# Build a synthetic source set example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 1: Source Set Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: source set checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 2: Mixture Weight Check (*)
#
# Build a synthetic mixture weight example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 2: Mixture Weight Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: mixture weight checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 3: Token Budget Check (*)
#
# Build a synthetic token budget example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 3: Token Budget Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: token budget checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 4: Manifest Check (**)
#
# Build a synthetic manifest example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 4: Manifest Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: manifest checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 5: Shard Check (**)
#
# Build a synthetic shard example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 5: Shard Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: shard checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 6: Split Check (**)
#
# Build a synthetic split example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 6: Split Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: split checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 7: Packing Check (**)
#
# Build a synthetic packing example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 7: Packing Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: packing checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 8: Source Set Check (***)
#
# Build a synthetic source set example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 8: Source Set Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: source set checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 9: Mixture Weight Check (***)
#
# Build a synthetic mixture weight example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 9: Mixture Weight Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: mixture weight checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")

# %% [markdown]
# ## Exercise 10: Token Budget Check (***)
#
# Build a synthetic token budget example, compute a validation statistic, and explain the pipeline implication.

# %%
# Your Solution
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
]
result = None
print("result:", result)

# %%
# Solution
header("Exercise 10: Token Budget Check")
records = [
    {"id": "a", "text": "alpha beta gamma", "source": "web"},
    {"id": "b", "text": "alpha beta", "source": "code"},
    {"id": "c", "text": "delta epsilon zeta eta", "source": "books"},
]
lengths = np.array([token_count(r["text"]) for r in records])
ids = [stable_hash(r)[:10] for r in records]
source_counts = Counter(r["source"] for r in records)
check_true("ids are unique", len(set(ids)) == len(records))
check_true("all token counts positive", np.all(lengths > 0))
check_close("source count total", sum(source_counts.values()), len(records))
print("ids:", ids)
print("lengths:", lengths)
print("source_counts:", dict(source_counts))
print("\nTakeaway: token budget checks should produce explicit counts, hashes, and validation signals before the next pipeline stage.")
